# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set_theme(style="darkgrid")

# %%
train=pd.read_csv("Downloads/train.csv")
test=pd.read_csv("Downloads/test.csv")

# %%
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
train.shape
# Out:
# (891, 12)

# %%
train.isna().sum()
# Out:
# PassengerId         0
# Survived            0
# Pclass              0
# Name                0
# Sex                 0
# Age               177
# SibSp               0
# Parch               0
# Ticket              0
# Fare                0
# Cabin             687
# Embarked            2
# cabin_multiple      0
# cabin_l           687
# ticket_letters      0
# M                   0
# dtype: int64

# %%
train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
numeric = train[['Age','SibSp','Parch','Fare']]
categorical = train[['Survived','Pclass','Sex','Ticket','Cabin','Embarked']]

# %%
for i in numeric.columns:
    plt.hist(numeric[i])
    plt.title(i)
    plt.show()

# %%
for i in numeric.columns:
    sns.distplot(numeric[i])
    plt.title(i)
    plt.show()
# Out:
# D:\python\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# D:\python\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# D:\python\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
# ...

# %%
sns.heatmap(numeric.corr(),annot=True,cmap="YlGnBu")
plt.title("Correlation matrix");

# %%
plt.figure(figsize=(10,8))
sns.heatmap(train.corr(),annot=True,cmap="YlGnBu");

# %%
pd.pivot_table(train, index = 'Survived', values = numeric)
# Out:
#                 Age       Fare     Parch     SibSp
# Survived
# 0         30.626179  22.117887  0.329690  0.553734
# 1         28.343690  48.395408  0.464912  0.473684

# %%
for i in categorical.columns :
    sns.barplot(categorical[i].value_counts().index,categorical[i].value_counts())
    if (i=="Ticket")|(i=="Cabin"):
        continue
    plt.title(i)
    plt.show()
# Out:
# D:\python\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# D:\python\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# D:\python\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
train["cabin_multiple"]=train["Cabin"].apply(lambda x : 0 if pd.isna(x) else len(x.split(" ")))
train.cabin_multiple.unique()
# Out:
# array([0, 1, 3, 2, 4], dtype=int64)

# %%
train["cabin_l"]=train["Cabin"].str[0]

# %%
train.groupby("Survived").mean()[["Age"]]
# Out:
#                 Age
# Survived
# 0         30.626179
# 1         28.343690

# %%
women_s=train.loc[train["Sex"]=="female"]
survived=women_s["Survived"].sum()
length=list(women_s.shape)[0]
per=(survived*100/length).round(2)
print(f"The percentage of survived women is {per} %.")
# Out:
# The percentage of survived women is 74.2 %.

# %%
survived
# Out:
# 233

# %%
men_s=train.loc[train["Sex"]=="male"]
survivedm=men_s["Survived"].sum()
lengthm=list(men_s.shape)[0]
per1=(survivedm*100/lengthm).round(2)
print(f"The percentage of survived men is {per1} %.")
# Out:
# The percentage of survived men is 18.89 %.

# %%
plt.bar((train["Survived"].value_counts().index),train.groupby("Survived").mean()["Age"],color="g",width=0.2)
plt.xticks(np.array([x for x , i in train.groupby("Survived")]).astype(int));

# %%
train.boxplot(column="Age",by="Survived")
plt.ylabel("Age")
plt.title("");

# %%
train.groupby("Sex").sum()[["Survived"]]
# Out:
#         Survived
# Sex
# female       233
# male         109

# %%
sns.countplot(x="Survived",hue="Sex",data=train)
plt.xticks([0,1],["Survived","Didn't survive"],rotation=45);

# %%
plt.bar(train["Sex"].value_counts().index,train.groupby("Sex").sum()["Survived"],width=0.2)
plt.xticks(["male","female"],["female","male"]);

# %%
train.groupby("Pclass").count()[["Survived"]]
# Out:
#         Survived
# Pclass
# 1            216
# 2            184
# 3            491

# %%
sns.countplot(x="Survived",hue="Pclass",data=train)
plt.xticks([0,1],["Survived","Didn't survive"],rotation=45);

# %%
train['ticket_letters'] = train.Ticket.apply(lambda x: ''.join(x.split(' ')[:-1]).replace('.','').replace('/','').lower() if len(x.split(' ')[:-1]) >0 else 0)

# %%
sns.countplot(train['ticket_letters'])
plt.xticks(rotation="vertical");
# Out:
# D:\python\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
train["M"]=train["Name"].apply(lambda x : x.split(",")[1].split(".")[0].strip())
plt.bar([x for x, i in train.groupby("M")],train.groupby("M").count()["Age"])
plt.xticks(rotation="vertical");

# %%
train.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'cabin_multiple',
#        'cabin_l', 'ticket_letters', 'M'],
#       dtype='object')

# %%
sns.countplot(train.Embarked);
# Out:
# D:\python\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
y=train["Survived"]
f=["Pclass","Sex","SibSp","Parch"]
x=pd.get_dummies(train[f])
x_test=pd.get_dummies(test[f])

# %%
mlr=RandomForestClassifier(n_estimators=200,max_depth=8,random_state=1)
mlr.fit(x,y)
predict=mlr.predict(x_test)

# %%
output = pd.DataFrame({'PassengerId': test.PassengerId, 'Survived': predict})
output.to_csv('submission.csv', index=False)

# %%
output1=output[output["Survived"]==1]
output1
# Out:
#      PassengerId  Survived
# 6            898         1
# 7            899         1
# 8            900         1
# 12           904         1
# 14           906         1
# ..           ...       ...
# 408         1300         1
# 410         1302         1
# 411         1303         1
# 412         1304         1
# 414         1306         1
#
# [134 rows x 2 columns]
